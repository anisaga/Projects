# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline
#import libraries

# %%
df=pd.read_csv("universities_data.csv")
df.head() #import file
# Out:
#    ID number                                 Name  year    code       state  \
# 0     100654             Alabama A & M University  2013  1000.0     Alabama
# 1     100663  University of Alabama at Birmingham  2013  2000.0      Alaska
# 2     100690                   Amridge University  2013  4000.0     Arizona
# 3     100706  University of Alabama in Huntsville  2013  5000.0    Arkansas
# 4     100724             Alabama State University  2013  6000.0  California
#
#       region  gdp_million    ZIP code  \
# 0      South     191481.0       35762
# 1       West      56622.8  35294-0110
# 2  Southwest     275199.1  36117-3553
# 3      South     114251.5       35899
# 4       West    2262771.2  36104-0271
#
#                               Highest degree offered        County name  ...  \
# 0             Doctor's degree - research/scholarship     Madison County  ...
# 1  Doctor's degree - research/scholarship and pro...   Jefferson County  ...
# ...

# %%
df.info() #info about file
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1534 entries, 0 to 1533
# Columns: 149 entries, ID number to Endowment assets (year end) per FTE enrollment (FASB)
# dtypes: float64(116), int64(2), object(31)
# memory usage: 1.7+ MB

# %%
df.duplicated().sum() #check dupluication
# Out:
# 0

# %%
df.isnull().sum() #check null values
# Out:
# ID number                                                   0
# Name                                                        0
# year                                                        0
# code                                                     1483
# state                                                    1483
#                                                          ...
# Percent of freshmen receiving student loan aid             42
# Percent of freshmen receiving federal student loans        42
# Percent of freshmen receiving other loan aid               42
# Endowment assets (year end) per FTE enrollment (GASB)    1018
# Endowment assets (year end) per FTE enrollment (FASB)     574
# Length: 149, dtype: int64

# %%
df.replace("",np.nan,inplace=True) #replace null value

# %%
df.nunique() #no of unique columns
# Out:
# ID number                                                1534
# Name                                                     1517
# year                                                        1
# code                                                       51
# state                                                      51
#                                                          ...
# Percent of freshmen receiving student loan aid             97
# Percent of freshmen receiving federal student loans        98
# Percent of freshmen receiving other loan aid               46
# Endowment assets (year end) per FTE enrollment (GASB)     506
# Endowment assets (year end) per FTE enrollment (FASB)     950
# Length: 149, dtype: int64

# %%
df.columns #columns
# Out:
# Index(['ID number', 'Name', 'year', 'code', 'state', 'region', 'gdp_million',
#        'ZIP code', 'Highest degree offered', 'County name',
#        ...
#        'Percent of freshmen receiving federal grant aid',
#        'Percent of freshmen receiving Pell grants',
#        'Percent of freshmen receiving other federal grant aid',
#        'Percent of freshmen receiving state/local grant aid',
#        'Percent of freshmen receiving institutional grant aid',
#        'Percent of freshmen receiving student loan aid',
#        'Percent of freshmen receiving federal student loans',
#        'Percent of freshmen receiving other loan aid',
#        'Endowment assets (year end) per FTE enrollment (GASB)',
#        'Endowment assets (year end) per FTE enrollment (FASB)'],
#       dtype='object', length=149)

# %%
df.describe() #describe columns
# Out:
#            ID number    year          code   gdp_million  Applicants total  \
# count    1534.000000  1534.0     51.000000  5.100000e+01       1377.000000
# mean   189091.037810  2013.0  28960.784314  3.268928e+05       6391.193174
# std     58641.915456     0.0  15832.827649  4.088304e+05       8787.469171
# min    100654.000000  2013.0   1000.000000  2.909880e+04          0.000000
# 25%    153148.500000  2013.0  16500.000000  8.209975e+04       1488.000000
# 50%    186508.000000  2013.0  29000.000000  1.830149e+05       3350.000000
# 75%    215730.000000  2013.0  41500.000000  4.260313e+05       7016.000000
# max    456490.000000  2013.0  56000.000000  2.262771e+06      72676.000000
#
#        Admissions total  Enrolled total  \
# count       1377.000000     1377.000000
# mean        3554.880174     1043.046478
# std         4309.457606     1285.165519
# min            0.000000        0.000000
# 25%          950.000000      287.000000
# 50%         2056.000000      538.000000
# ...

# %%
df.describe(include=object)#object data type columns
# Out:
#                        Name    state region ZIP code Highest degree offered  \
# count                  1534       51     51     1534                   1534
# unique                 1517       51      6     1513                      6
# top     Westminster College  Alabama  South     5401        Master's degree
# freq                      3        1     12        2                    587
#
#                County name Longitude location of institution  \
# count                 1534                              1534
# unique                 629                              1521
# top     Los Angeles County                         -9,52,638
# freq                    28                                 2
#
#        Latitude location of institution Religious affiliation  \
# count                              1534                  1532
# unique                             1533                    54
# top                           42,97,476        Not applicable
# ...

# %%
print (df.columns[:40]) #first 40 columns
# Out:
# Index(['ID number', 'Name', 'year', 'code', 'state', 'region', 'gdp_million',
#        'ZIP code', 'Highest degree offered', 'County name',
#        'Longitude location of institution', 'Latitude location of institution',
#        'Religious affiliation', 'Offers Less than one year certificate',
#        'Offers One but less than two years certificate',
#        'Offers Associate's degree',
#        'Offers Two but less than 4 years certificate',
#        'Offers Bachelor's degree', 'Offers Postbaccalaureate certificate',
#        'Offers Master's degree', 'Offers Post-master's certificate',
#        'Offers Doctor's degree - research/scholarship',
#        'Offers Doctor's degree - professional practice',
#        'Offers Doctor's degree - other', 'Offers Other degree',
#        'Applicants total', 'Admissions total', 'Enrolled total',
#        'Percent of freshmen submitting SAT scores',
#        'Percent of freshmen submitting ACT scores',
# ...

# %%
print(df.columns[40:80]) #middle columns
# Out:
# Index(['Estimated enrollment, part time',
#        'Estimated undergraduate enrollment, total',
#        'Estimated undergraduate enrollment, full time',
#        'Estimated undergraduate enrollment, part time',
#        'Estimated freshman undergraduate enrollment, total',
#        'Estimated freshman enrollment, full time',
#        'Estimated freshman enrollment, part time',
#        'Estimated graduate enrollment, total',
#        'Estimated graduate enrollment, full time',
#        'Estimated graduate enrollment, part time',
#        'Associate's degrees awarded', 'Bachelor's degrees awarded',
#        'Master's degrees awarded',
#        'Doctor's degrese - research/scholarship awarded',
#        'Doctor's degrees - professional practice awarded',
#        'Doctor's degrees - other awarded',
#        'Certificates of less than 1-year awarded',
#        'Certificates of 1 but less than 2-years awarded',
#        'Certificates of 2 but less than 4-years awarded',
# ...

# %%
print(df.columns[80:]) #last columns
# Out:
# Index(['Level of institution', 'Control of institution',
#        'Historically Black College or University', 'Tribal college',
#        'Degree of urbanization (Urban-centric locale)',
#        'Carnegie Classification 2010: Basic', 'Total enrollment',
#        'Full-time enrollment', 'Part-time enrollment',
#        'Undergraduate enrollment', 'Graduate enrollment',
#        'Full-time undergraduate enrollment',
#        'Part-time undergraduate enrollment',
#        'Percent of total enrollment that are American Indian or Alaska Native',
#        'Percent of total enrollment that are Asian',
#        'Percent of total enrollment that are Black or African American',
#        'Percent of total enrollment that are Hispanic/Latino',
#        'Percent of total enrollment that are Native Hawaiian or Other Pacific Islander',
#        'Percent of total enrollment that are White',
#        'Percent of total enrollment that are two or more races',
# ...

# %%
columns=['Name','state','gdp_million', 'Applicants total', 'Admissions total', 'Enrolled total','Tuition and fees, 2013-14','Total price for in-state students living on campus 2013-14',
       'Total price for out-of-state students living on campus 2013-14','Control of institution','Highest degree offered','State abbreviation','Degree of urbanization (Urban-centric locale)','Percent admitted - total','Graduate enrollment']
df1=df[columns]
df1.head() #impt columns to answer analysis
# Out:
#                                   Name       state  gdp_million  \
# 0             Alabama A & M University     Alabama     191481.0
# 1  University of Alabama at Birmingham      Alaska      56622.8
# 2                   Amridge University     Arizona     275199.1
# 3  University of Alabama in Huntsville    Arkansas     114251.5
# 4             Alabama State University  California    2262771.2
#
#    Applicants total  Admissions total  Enrolled total  \
# 0            6142.0            5521.0          1104.0
# 1            5689.0            4934.0          1773.0
# 2               NaN               NaN             NaN
# 3            2054.0            1656.0           651.0
# 4           10245.0            5251.0          1479.0
#
#    Tuition and fees, 2013-14  \
# 0                     7182.0
# 1                     7206.0
# 2                     6870.0
# 3                     9192.0
# 4                     8720.0
#
#    Total price for in-state students living on campus 2013-14  \
# ...

# %%
df1.columns #columns for new data
# Out:
# Index(['Name', 'state', 'gdp_million', 'Applicants total', 'Admissions total',
#        'Enrolled total', 'Tuition and fees, 2013-14',
#        'Total price for in-state students living on campus 2013-14',
#        'Total price for out-of-state students living on campus 2013-14',
#        'Control of institution', 'Highest degree offered',
#        'State abbreviation', 'Degree of urbanization (Urban-centric locale)',
#        'Percent admitted - total', 'Graduate enrollment'],
#       dtype='object')

# %%
df1.info() #info about new columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1534 entries, 0 to 1533
# Data columns (total 15 columns):
#  #   Column                                                          Non-Null Count  Dtype
# ---  ------                                                          --------------  -----
#  0   Name                                                            1534 non-null   object
#  1   state                                                           51 non-null     object
#  2   gdp_million                                                     51 non-null     float64
#  3   Applicants total                                                1377 non-null   float64
#  4   Admissions total                                                1377 non-null   float64
#  5   Enrolled total                                                  1377 non-null   float64
#  6   Tuition and fees, 2013-14                                       1497 non-null   float64
# ...

# %%
df1.isnull().sum() #null values
# Out:
# Name                                                                 0
# state                                                             1483
# gdp_million                                                       1483
# Applicants total                                                   157
# Admissions total                                                   157
# Enrolled total                                                     157
# Tuition and fees, 2013-14                                           37
# Total price for in-state students living on campus 2013-14         134
# Total price for out-of-state students living on campus 2013-14     134
# Control of institution                                               0
# Highest degree offered                                               0
# State abbreviation                                                   0
# Degree of urbanization (Urban-centric locale)                        0
# ...

# %%
df1.duplicated().sum() #duplicated values
# Out:
# 0

# %%
df1.describe()#descriptive statistics of columns
# Out:
#         gdp_million  Applicants total  Admissions total  Enrolled total  \
# count  5.100000e+01       1377.000000       1377.000000     1377.000000
# mean   3.268928e+05       6391.193174       3554.880174     1043.046478
# std    4.088304e+05       8787.469171       4309.457606     1285.165519
# min    2.909880e+04          0.000000          0.000000        0.000000
# 25%    8.209975e+04       1488.000000        950.000000      287.000000
# 50%    1.830149e+05       3350.000000       2056.000000      538.000000
# 75%    4.260313e+05       7016.000000       4203.000000     1246.000000
# max    2.262771e+06      72676.000000      35815.000000    10241.000000
#
#        Tuition and fees, 2013-14  \
# count                1497.000000
# mean                20727.490314
# std                 12455.805360
# min                  1032.000000
# 25%                  8542.000000
# 50%                 20060.000000
# 75%                 29992.000000
# max                 49138.000000
#
# ...

# %%
df1.describe(include=object) #object data types
# Out:
#                        Name    state  Control of institution  \
# count                  1534       51                    1534
# unique                 1517       51                       2
# top     Westminster College  Alabama  Private not-for-profit
# freq                      3        1                     971
#
#        Highest degree offered State abbreviation  \
# count                    1534               1534
# unique                      6                 51
# top           Master's degree           New York
# freq                      587                122
#
#        Degree of urbanization (Urban-centric locale)
# count                                           1534
# unique                                            12
# top                                      City: Large
# freq                                             294

# %% [markdown]
# ## ***Three question for institute
# 1. Enrollment rate

# %%
df1['enrol_rate']=(df1['Enrolled total']/df1['Admissions total']*100)
#to find enrollment rate of students

# %%
df1.head() #enrol rate column created
# Out:
#                                   Name       state  gdp_million  \
# 0             Alabama A & M University     Alabama     191481.0
# 1  University of Alabama at Birmingham      Alaska      56622.8
# 2                   Amridge University     Arizona     275199.1
# 3  University of Alabama in Huntsville    Arkansas     114251.5
# 4             Alabama State University  California    2262771.2
#
#    Applicants total  Admissions total  Enrolled total  \
# 0            6142.0            5521.0          1104.0
# 1            5689.0            4934.0          1773.0
# 2               NaN               NaN             NaN
# 3            2054.0            1656.0           651.0
# 4           10245.0            5251.0          1479.0
#
#    Tuition and fees, 2013-14  \
# 0                     7182.0
# 1                     7206.0
# 2                     6870.0
# 3                     9192.0
# 4                     8720.0
#
#    Total price for in-state students living on campus 2013-14  \
# ...

# %% [markdown]
# ##****Graduation rate

# %%
df1['graduation_rate']=(df1['Graduate enrollment']/df1['Enrolled total']*100) #graduation rate column created

# %%
df1.head()
# Out:
#                                   Name       state  gdp_million  \
# 0             Alabama A & M University     Alabama     191481.0
# 1  University of Alabama at Birmingham      Alaska      56622.8
# 2                   Amridge University     Arizona     275199.1
# 3  University of Alabama in Huntsville    Arkansas     114251.5
# 4             Alabama State University  California    2262771.2
#
#    Applicants total  Admissions total  Enrolled total  \
# 0            6142.0            5521.0          1104.0
# 1            5689.0            4934.0          1773.0
# 2               NaN               NaN             NaN
# 3            2054.0            1656.0           651.0
# 4           10245.0            5251.0          1479.0
#
#    Tuition and fees, 2013-14  \
# 0                     7182.0
# 1                     7206.0
# 2                     6870.0
# 3                     9192.0
# 4                     8720.0
#
#    Total price for in-state students living on campus 2013-14  \
# ...

# %% [markdown]
# #lucrative college in terms of passrate and cost

# %%
pass_rate=df1.sort_values(by='graduation_rate',ascending=False)
pass_rate.head(20) #pass rate of students
# Out:
#                                                    Name state  gdp_million  \
# 99                 Golden Gate University-San Francisco   NaN          NaN
# 1343                                    Goddard College   NaN          NaN
# 1479                                Brandman University   NaN          NaN
# 316                           National Louis University   NaN          NaN
# 67                     Alliant International University   NaN          NaN
# 1046                              Marylhurst University   NaN          NaN
# 195                      Carlos Albizu University-Miami   NaN          NaN
# 396                  Maharishi University of Management   NaN          NaN
# 699                                  Webster University   NaN          NaN
# 218                        Nova Southeastern University   NaN          NaN
# 1476                         Antioch University-Seattle   NaN          NaN
# ...

# %%
pass_rate.head(5)['Name'] #top colleges on basis of passing rate
# Out:
# 99      Golden Gate University-San Francisco
# 1343                         Goddard College
# 1479                     Brandman University
# 316                National Louis University
# 67          Alliant International University
# Name: Name, dtype: object

# %%
cost=df1.sort_values(by='Tuition and fees, 2013-14',ascending=False)
cost.head(20) #on basis of cost
# Out:
#                                              Name state  gdp_million  \
# 793   Columbia University in the City of New York   NaN          NaN
# 858                        Sarah Lawrence College   NaN          NaN
# 897                                Vassar College   NaN          NaN
# 1072                   Carnegie Mellon University   NaN          NaN
# 289                         University of Chicago   NaN          NaN
# 176                               Trinity College   NaN          NaN
# 188                  George Washington University   NaN          NaN
# 177                           Wesleyan University   NaN          NaN
# 477                Tulane University of Louisiana   NaN          NaN
# 1068                          Bucknell University   NaN          NaN
# 991                               Oberlin College   NaN          NaN
# 894                                 Union College   NaN          NaN
# 734                             Dartmouth College   NaN          NaN
# ...

# %%
cost.head(5)['Name']#top colleges on high cost of tuition fee
# Out:
# 793     Columbia University in the City of New York
# 858                          Sarah Lawrence College
# 897                                  Vassar College
# 1072                     Carnegie Mellon University
# 289                           University of Chicago
# Name: Name, dtype: object

# %%
###Qualitative and quantitative analysis

# %% [markdown]
# #****1.Do universities with a high number of applications are the preferred ones by students? ***
#      2.Do students prefer universities that have a high rate of admission? in other words, do students prefer a university where it is easier for them to be admitted?

# %%
plt.figure(figsize=(12,5),dpi=200) #correlation between applicant and admission along wioth enrolment
sns.scatterplot(x='Applicants total',y='Admissions total',hue='Enrolled total',data=df1)
# Out:
# <Axes: xlabel='Applicants total', ylabel='Admissions total'>

# %% [markdown]
# ##Universities with more applicants are most preferred one and make more enrollments
# ###Also universities with more admissions have high admittence rate are preferred by students and have more application

# %% [markdown]
# ####3.	Do students prefer public or private universities?

# %%
plt.figure(figsize=(12,5),dpi=200) #find no of public and private university
sns.countplot(x='Control of institution',data=df1) #more private university available
# Out:
# <Axes: xlabel='Control of institution', ylabel='count'>

# %%
plt.figure(figsize=(12,5),dpi=200) #total enrollment on basis of institution
sns.barplot(x='Control of institution',y='Enrolled total',data=df1)
# Out:
# <Axes: xlabel='Control of institution', ylabel='Enrolled total'>

# %% [markdown]
# #more students enrolled in public universities

# %%
plt.figure(figsize=(12,5),dpi=200)#total applicants received on institute types
sns.barplot(x='Control of institution',y='Applicants total',data=df1)
# Out:
# <Axes: xlabel='Control of institution', ylabel='Applicants total'>

# %% [markdown]
# #More students applied for public universities

# %% [markdown]
# ##4.Do students prefer universities with low tuition and fees?

# %%
plt.figure(figsize=(12,5),dpi=200) #application received on basis of tuition fee
sns.scatterplot(x='Applicants total',y='Tuition and fees, 2013-14',hue='Enrolled total',data=df1)
# Out:
# <Axes: xlabel='Applicants total', ylabel='Tuition and fees, 2013-14'>

# %% [markdown]
# ##when tuition fees are high ,applicants are less and enrollment is also less

# %%
plt.figure(figsize=(12,5),dpi=200) #fees received by institute
sns.barplot(x='Control of institution',y='Tuition and fees, 2013-14',data=df1)
# Out:
# <Axes: xlabel='Control of institution', ylabel='Tuition and fees, 2013-14'>

# %% [markdown]
# ##Tuition fees higher in private so most preferr public universities

# %% [markdown]
# ##5.	Do students prefer a university for its low on-campus cost of living?

# %%
plt.figure(figsize=(12,5),dpi=200) #based opn campus living cost and applicant
sns.scatterplot(x='Total price for in-state students living on campus 2013-14',y='Applicants total',hue='Enrolled total',data=df1)
# Out:
# <Axes: xlabel='Total price for in-state students living on campus 2013-14', ylabel='Applicants total'>

# %% [markdown]
# #students not preferred high on campus cost of living and more enrolment rate in lower tuition fee

# %% [markdown]
# 6.	Do students prefer universities from highly populated states?

# %%
populated_states=['California','Texas','Newyork','Ohio','Florida']
df1['populated']=df1['state'].apply(lambda x: 'High' if x in populated_states else 'Low' )
df1.head() #find high and low populated state
# Out:
#                                   Name       state  gdp_million  \
# 0             Alabama A & M University     Alabama     191481.0
# 1  University of Alabama at Birmingham      Alaska      56622.8
# 2                   Amridge University     Arizona     275199.1
# 3  University of Alabama in Huntsville    Arkansas     114251.5
# 4             Alabama State University  California    2262771.2
#
#    Applicants total  Admissions total  Enrolled total  \
# 0            6142.0            5521.0          1104.0
# 1            5689.0            4934.0          1773.0
# 2               NaN               NaN             NaN
# 3            2054.0            1656.0           651.0
# 4           10245.0            5251.0          1479.0
#
#    Tuition and fees, 2013-14  \
# 0                     7182.0
# 1                     7206.0
# 2                     6870.0
# 3                     9192.0
# 4                     8720.0
#
#    Total price for in-state students living on campus 2013-14  \
# ...

# %%
plt.figure(figsize=(12,5),dpi=200) #find applicants and population
sns.barplot(x='populated',y='Applicants total',data=df1)
# Out:
# <Axes: xlabel='populated', ylabel='Applicants total'>

# %% [markdown]
# #students preferred higly populated states than low populated states

# %% [markdown]
# #7.	Do students prefer a university because it belongs to a state with a high GDP per capita?

# %%
gdp=df1.sort_values(by='gdp_million',ascending=False)
gdp.head(20)#find gdp is high or low
# Out:
#                                                  Name           state  \
# 4                            Alabama State University      California
# 43                             University of Arkansas           Texas
# 32  American Indian College of the Assemblies of G...        New York
# 9                         Birmingham Southern College         Florida
# 13                      Jacksonville State University        Illinois
# 38                                   Prescott College    Pennsylvania
# 35      Embry-Riddle Aeronautical University-Prescott            Ohio
# 30                     University of Alaska Southeast      New Jersey
# 10                          Concordia College Alabama         Georgia
# 33                     Arizona State University-Tempe  North Carolina
# 46                           Arkansas Tech University        Virginia
# 21                                 Samford University   Massachusetts
# ...

# %%
high_gdp=['Massachusetts','Connecticut','New york','California','New jersey']

df1['gdp']=df1['state'].apply(lambda x:'High gdp' if x in high_gdp else 'Low gdp') #create columns with label of high or low gdp

# %%
plt.figure(figsize=(12,5),dpi=200) #find gdp and applicants
sns.barplot(x='gdp',y='Applicants total',data=df1)
# Out:
# <Axes: xlabel='gdp', ylabel='Applicants total'>

# %% [markdown]
# #gdp not have huge difference

# %%
8.	Do students prefer a university based on the possibility of a higher, additional academic degree in the same university?
# Out:
# Object `university` not found.

# %%
df1['Highest degree offered'].unique() #unique columns of highest degree offered
# Out:
# array(["Doctor's degree - research/scholarship",
#        "Doctor's degree - research/scholarship and professional practice",
#        "Bachelor's degree", "Doctor's degree - professional practice",
#        "Master's degree", "Doctor's degree - other"], dtype=object)

# %%
plt.figure(figsize=(12,5),dpi=200)
sns.barplot(x='Highest degree offered',y='Applicants total',data=df1)

plt.xticks(rotation=90)
plt.show() #relati0nship between applicant and highest degree offering colleges

# %% [markdown]
# #More candidates preferred doctor's degree

# %% [markdown]
# ###Conclusion:
#  High applicants have high enrollment ,some colleges have low admittance rate still received more application because its more popular though
#  Public universities preferred more
#  Low tuition fee and low cost of living make students prefer public university
#  student prefer higher degree ofeering colleges
