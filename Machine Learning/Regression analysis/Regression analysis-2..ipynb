# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('ggplot')

import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline #import libraries

# %%
data = pd.read_csv('kc_house_data.csv')
data.head(10) #read data
# Out:
#            id             date      price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000   221900.0         3       1.00         1180
# 1  6414100192  20141209T000000   538000.0         3       2.25         2570
# 2  5631500400  20150225T000000   180000.0         2       1.00          770
# 3  2487200875  20141209T000000   604000.0         4       3.00         1960
# 4  1954400510  20150218T000000   510000.0         3       2.00         1680
# 5  7237550310  20140512T000000  1225000.0         4       4.50         5420
# 6  1321400060  20140627T000000   257500.0         3       2.25         1715
# 7  2008000270  20150115T000000   291850.0         3       1.50         1060
# 8  2414600126  20150415T000000   229500.0         3       1.00         1780
# 9  3793500160  20150312T000000   323000.0         3       2.50         1890
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# ...

# %%
data.duplicated().sum() #check duplicates
# Out:
# 0

# %%
data.isnull().sum() #checek missing values
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
data.nunique() #no of unique columns
# Out:
# id               21436
# date               372
# price             4028
# bedrooms            13
# bathrooms           30
# sqft_living       1038
# sqft_lot          9782
# floors               6
# waterfront           2
# view                 5
# condition            5
# grade               12
# sqft_above         946
# sqft_basement      306
# yr_built           116
# yr_renovated        70
# zipcode             70
# lat               5034
# long               752
# sqft_living15      777
# sqft_lot15        8689
# dtype: int64

# %%
data.dtypes #check data types of colummns
# Out:
# id                 int64
# date              object
# price            float64
# bedrooms           int64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# grade              int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# zipcode            int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object

# %%
plt.figure(figsize = (16,5), dpi = 200)
sns.scatterplot(x='price',y='sqft_lot',data = data) #sq_lot does not affect price
# Out:
# <Axes: xlabel='price', ylabel='sqft_lot'>

# %%
plt.figure(figsize = (16,5), dpi = 200)
sns.scatterplot(x='sqft_living15',y='price',data = data) #increase in sq_ft_living15 increase its price too
# Out:
# <Axes: xlabel='sqft_living15', ylabel='price'>

# %%
plt.figure(figsize = (12,5), dpi = 200)
sns.distplot(data['price'],hist=False) #price column been represented graphically
# Out:
# <Axes: xlabel='price', ylabel='Density'>

# %%
plt.figure(figsize=(12,6))
sns.boxplot(x='bathrooms',y='price',data=data)#when no of bathrooms more so as the price
# Out:
# <Axes: xlabel='bathrooms', ylabel='price'>

# %%
plt.figure(figsize=(12,6))
sns.boxplot(x='bedrooms',y='price',data=data) #no of bedrooom increase the price too
# Out:
# <Axes: xlabel='bedrooms', ylabel='price'>

# %%
plt.figure(figsize=(12,6))
sns.boxplot(x='grade',y='price',data=data) #grade of house will increase its price too
# Out:
# <Axes: xlabel='grade', ylabel='price'>

# %%
plt.figure(figsize=(12,6))
sns.scatterplot(x='lat',y='price',data=data) #high latitude means high price
# Out:
# <Axes: xlabel='lat', ylabel='price'>

# %%
plt.figure(figsize=(12,6))
sns.scatterplot(x='long',y='price',data=data) #long doesnt directly affects price
# Out:
# <Axes: xlabel='long', ylabel='price'>

# %%
plt.figure(figsize=(12,6))
sns.scatterplot(x='long',y='lat',hue='price',data=data) #lat directly influence price than long
# Out:
# <Axes: xlabel='long', ylabel='lat'>

# %%
plt.figure(figsize=(12,6))
sns.boxplot(x='waterfront',y='price',data=data) #waterfront affects price too
# Out:
# <Axes: xlabel='waterfront', ylabel='price'>

# %%
plt.figure(figsize=(12,6))
sns.barplot(x='waterfront',y='price',data=data) #barplot represents waterfront with price
# Out:
# <Axes: xlabel='waterfront', ylabel='price'>

# %%
plt.figure(figsize=(12,6))
sns.countplot(x='view',data=data) #count values of view
# Out:
# <Axes: xlabel='view', ylabel='count'>

# %%
plt.figure(figsize=(12,6))
sns.barplot(x='view',y='price',data=data)  #view affects price too
# Out:
# <Axes: xlabel='view', ylabel='price'>

# %%
plt.figure(figsize=(12,6))
sns.boxplot(x='view',y='price',data=data)  #boxplot shows view and price column with its outliers
# Out:
# <Axes: xlabel='view', ylabel='price'>

# %%
plt.figure(figsize=(12,6))
sns.barplot(x='condition',y='price',data=data)       #condition of house affects price too
# Out:
# <Axes: xlabel='condition', ylabel='price'>

# %%
plt.figure(figsize=(12,6))
sns.boxplot(x='condition',y='price',data=data)   #boxplot shws condition with its influence on price and also its outliers
# Out:
# <Axes: xlabel='condition', ylabel='price'>

# %%
plt.figure(figsize=(12,6))
sns.scatterplot(x='sqft_living',y='price',data=data) #size of sqft_living directly affects its price too
# Out:
# <Axes: xlabel='sqft_living', ylabel='price'>

# %%
data.info() #info about the data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
data['date'].head() #check data column
# Out:
# 0    20141013T000000
# 1    20141209T000000
# 2    20150225T000000
# 3    20141209T000000
# 4    20150218T000000
# Name: date, dtype: object

# %%
data=data.drop(['date','id','zipcode'],axis=1) #drop this column which is least significant

# %%
data.columns #columns in data
# Out:
# Index(['price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors',
#        'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'lat', 'long',
#        'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
cols=['bedrooms','bathrooms','sqft_living','grade','lat','long','view','condition']
X=data[cols]
Y=data[['price']] #feature engineering

# %%
X.head(10) #first feew columns of independent features
# Out:
#    bedrooms  bathrooms  sqft_living  grade      lat     long  view  condition
# 0         3       1.00         1180      7  47.5112 -122.257     0          3
# 1         3       2.25         2570      7  47.7210 -122.319     0          3
# 2         2       1.00          770      6  47.7379 -122.233     0          3
# 3         4       3.00         1960      7  47.5208 -122.393     0          5
# 4         3       2.00         1680      8  47.6168 -122.045     0          3
# 5         4       4.50         5420     11  47.6561 -122.005     0          3
# 6         3       2.25         1715      7  47.3097 -122.327     0          3
# 7         3       1.50         1060      7  47.4095 -122.315     0          3
# 8         3       1.00         1780      7  47.5123 -122.337     0          3
# 9         3       2.50         1890      7  47.3684 -122.031     0          3

# %%
Y.head() #first few columns of dependent features
# Out:
#       price
# 0  221900.0
# 1  538000.0
# 2  180000.0
# 3  604000.0
# 4  510000.0

# %%
print('Independent Feature Set Shape : ', X.shape)
print('Dependent Feature Shape       : ', Y.shape)#check shape of our feattures
# Out:
# Independent Feature Set Shape :  (21613, 8)
# Dependent Feature Shape       :  (21613, 1)

# %%
# Splitting The Data into training and test sets
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X,Y, test_size = 0.2, random_state = 2)

# %%
print('Training Data Shape   : ', x_train.shape)
print('Training Labels Shape : ', y_train.shape)
print('Testing Data Shape    : ', x_test.shape)
print('Testing Labels Shape  : ', y_test.shape) #check shape of our data after train and test splitting
# Out:
# Training Data Shape   :  (17290, 8)
# Training Labels Shape :  (17290, 1)
# Testing Data Shape    :  (4323, 8)
# Testing Labels Shape  :  (4323, 1)

# %%
# Scaling
cols = ['sqft_living','lat','long','grade']
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# Fit on training set
scaler.fit(x_train[cols])

# Tranform training and testing sets
x_train[cols] = scaler.transform(x_train[cols])
x_test[cols]  = scaler.transform(x_test[cols])

# %%
x_train.head(10) #after scaling check data
# Out:
#        bedrooms  bathrooms  sqft_living  grade       lat      long  view  \
# 15166         4       4.00     0.298801    0.9  0.950619  0.117110     2
# 13416         4       2.00     0.132705    0.4  0.968474  0.161130     0
# 206           3       2.50     0.177226    0.5  0.886923  0.336379     0
# 4286          3       2.75     0.131849    0.5  0.252373  0.144518     0
# 18065         4       2.50     0.150685    0.5  0.362876  0.290698     0
# 19714         4       2.50     0.175514    0.5  0.520508  0.326412     0
# 15312         3       1.75     0.087329    0.4  0.482548  0.279070     0
# 6293          3       1.75     0.061644    0.4  0.169535  0.180233     0
# 16265         5       1.00     0.186644    0.6  0.729130  0.186877     0
# 466           3       1.75     0.095034    0.4  0.925205  0.137874     0
#
#        condition
# 15166          4
# 13416          3
# 206            3
# 4286           3
# 18065          3
# 19714          3
# 15312          5
# ...

# %%
x_test.head(10) #check testing data after scaling
# Out:
#        bedrooms  bathrooms  sqft_living  grade       lat      long  view  \
# 6638          4       2.25     0.174658    0.4  0.850893  0.118771     0
# 7366          3       1.50     0.154110    0.7  0.763712  0.357973     2
# 3158          2       1.00     0.092466    0.4  0.862956  0.164452     0
# 9117          5       3.25     0.353596    0.5  0.917323  0.196844     4
# 3392          2       1.00     0.041952    0.3  0.088467  0.443522     0
# 305           3       1.75     0.132705    0.5  0.752775  0.183555     0
# 14462         3       1.50     0.182363    0.4  0.601255  0.137043     0
# 6196          4       2.25     0.172089    0.5  0.687631  0.430233     0
# 10194         4       2.50     0.167808    0.5  0.527103  0.611296     0
# 13457         3       3.00     0.154966    0.5  0.857648  0.119601     0
#
#        condition
# 6638           5
# 7366           3
# 3158           3
# 9117           4
# 3392           3
# 305            4
# 14462          5
# ...

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(x_train, y_train)#1st reg model
# Out:
# LinearRegression()

# %%
regressor.intercept_          #B0 parameter
# Out:
# array([-463402.01063305])

# %%
regressor.coef_   #b1x parameter
# Out:
# array([[ -33292.70668983,   -2660.72980356, 2433362.18352043,
#          811086.05845451,  395188.4642967 , -270862.64038104,
#           84262.07167221,   52825.56231202]])

# %%
# Evaluation
print('Training Set Score : ', regressor.score(x_train, y_train))
print('Testing Set Score  : ', regressor.score(x_test, y_test))
# Out:
# Training Set Score :  0.6517558546568375
# Testing Set Score  :  0.6714122990666862

# %%
from sklearn.metrics import r2_score

pred_train = regressor.predict(x_train)
pred_test  = regressor.predict(x_test)

print('Training Set Score : ', r2_score(y_train, pred_train))
print('Testing Set Score  : ', r2_score(y_test, pred_test)) #check model performence
# Out:
# Training Set Score :  0.6517558546568375
# Testing Set Score  :  0.6714122990666862

# %%
from sklearn.tree import DecisionTreeRegressor
regressor = DecisionTreeRegressor(criterion = 'squared_error', max_depth = 13)
regressor.fit(x_train, y_train) #2 reg model
# Out:
# DecisionTreeRegressor(max_depth=13)

# %%
pred_train = regressor.predict(x_train)
pred_test  = regressor.predict(x_test) #prediction

# %%
from sklearn.metrics import r2_score
print('Training Set Score : ', r2_score(y_train, pred_train))
print('Testing Set Score  : ', r2_score(y_test, pred_test)) #model performence
# Out:
# Training Set Score :  0.9540803323479834
# Testing Set Score  :  0.7110893527508451

# %%
from sklearn.neighbors import KNeighborsRegressor
regressor = KNeighborsRegressor(n_neighbors =7)
regressor.fit(x_train, y_train) #3 reg model
# Out:
# KNeighborsRegressor(n_neighbors=7)

# %%
pred_train = regressor.predict(x_train)
pred_test  = regressor.predict(x_test) #prediction

from sklearn.metrics import r2_score
print('Training Set Score : ', r2_score(y_train, pred_train))
print('Testing Set Score  : ', r2_score(y_test, pred_test)) #model performence
# Out:
# Training Set Score :  0.7726567571651499
# Testing Set Score  :  0.6997447269510491

# %%
from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators = 40, max_depth = 6, max_features =5)
regressor.fit(x_train , y_train) #3 reg model
# Out:
# RandomForestRegressor(max_depth=6, max_features=5, n_estimators=40)

# %%
pred_train = regressor.predict(x_train)
pred_test  = regressor.predict(x_test) #prediction

from sklearn.metrics import r2_score
print('Training Set score : ', r2_score(y_train, pred_train))
print('Testing Set score  : ', r2_score(y_test, pred_test)) #model performence
# Out:
# Training Set score :  0.8245086030177162
# Testing Set score  :  0.7957952678423099

# %%
from xgboost import XGBRegressor
regressor = XGBRegressor(n_estimators = 50, max_depth = 8)
regressor.fit(x_train, y_train) #4 reg model
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=8, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=50, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
pred_train = regressor.predict(x_train)
pred_test  = regressor.predict(x_test) #prediction

print('Training Set Score : ', r2_score(y_train, pred_train))
print('Testing Set Score  : ', r2_score(y_test, pred_test)) # model performence
# Out:
# Training Set Score :  0.9705990859704888
# Testing Set Score  :  0.8524150627127222

# %%
from lightgbm import LGBMRegressor
regressor = LGBMRegressor(n_estimators = 50)
regressor.fit(x_train, y_train) #5 reg model
# Out:
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001074 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 825
# [LightGBM] [Info] Number of data points in the train set: 17290, number of used features: 8
# [LightGBM] [Info] Start training from score 539363.587970
# LGBMRegressor(n_estimators=50)

# %%
pred_train = regressor.predict(x_train)
pred_test  = regressor.predict(x_test) #prediction

print('Training Set Score : ', r2_score(y_train, pred_train))
print('Testing Set Score  : ', r2_score(y_test, pred_test)) #model performence
# Out:
# Training Set Score :  0.8983498847293419
# Testing Set Score  :  0.8672410684774235

# %%
from sklearn.tree import DecisionTreeRegressor
estimator = DecisionTreeRegressor(max_depth = 13, criterion = 'squared_error')

from sklearn.ensemble import AdaBoostRegressor
regressor = AdaBoostRegressor(estimator, 
                              n_estimators = 50)
regressor.fit(x_train, y_train) #6 reg model
# Out:
# AdaBoostRegressor(estimator=DecisionTreeRegressor(max_depth=13))

# %%
pred_train = regressor.predict(x_train)
pred_test  = regressor.predict(x_test) #prediction

print('Training Set Score : ', r2_score(y_train, pred_train))
print('Testing Set Score  : ', r2_score(y_test, pred_test)) #model performence
# Out:
# Training Set Score :  0.9821678773127539
# Testing Set Score  :  0.8258275610659378
